# %% [markdown]
# # Import packages

# %%
import matplotlib.pyplot as plt
import cv2
from pathlib import Path

from utils import getResult, testExpressionGenerator

# %% [markdown]
# # Run simple tests on Solver class

# %%
testExpressionGenerator()
# Out:
# -5.419489111728737e+18 -5.419489111728738e+18
# 2808921534514501.5 2808921534514501.0
# -3.9952589338298696e+18 -3.995258933829869e+18
# 3882871538830025.5 3882871538830026.0
# -3.5920831415488012e+16 -3.592083141548801e+16
# 4.2600453506677843e+27 4.260045350667785e+27
# 4.4047799791749857e+24 4.404779979174986e+24
# 2.203674180717561e+19 2.2036741807175606e+19
# -1.485483477920602e+19 -1.4854834779206021e+19
# 4.815270522312433e+27 4.8152705223124323e+27
# 1.7343277645567062e+16 1.7343277645567064e+16

# %% [markdown]
# # Run pipeline end to end

# %%
imgs_path = Path('./test_examples')
for img_path in imgs_path.glob('*.jpg'):
    img = cv2.imread(img_path.as_posix(), cv2.IMREAD_GRAYSCALE)
    plt.imshow(img)
    plt.show()
    solution, equation, _ = getResult(img)
    print(f"Rješenje: {equation} = {solution}")
# Out:
# Rješenje: (2+2)/2 = 2.0
# Rješenje: (3+4/2)x3 = 15.0
# Rješenje: (7-(1+5x4)4)x0+++5- = None
